# %% [markdown]
# # Extract EEG features
# Extract DE (Differential Entropy) features from the EEG data.
#
# Input: Processed samples in folder `REFED-dataset/data`
#
# Output: EEG features to folder *`'path_features'`*

# %%
import os
import numpy as np
from scipy.io import loadmat, savemat
from DE_PSD import DE_PSD

# %% [markdown]
# ### Feature extraction parameters

# %%
path_data = './REFED-dataset/data'
path_feature = './REFED-dataset/features'

# Parameters for DE and PSD
stft_para = {
    'stftn' :1000,               # number of points in STFT
    'fStart':[1, 4, 8, 14, 31],  # start frequency of each band
    'fEnd'  :[4, 8, 14, 31, 50], # end frequency of each band
    'fs'    :1000,               # sampling frequency
    'window':1,                  # window length in seconds
}

sub_list = os.listdir(path_data)

if not os.path.exists(path_feature):
    os.makedirs(path_feature)

# %% [markdown]
# ### Feature extraction function

# %%
def feature_EEG_sub(path_data, stft_para, save_path=None):
    '''
    Extract DE and PSD features from EEG data for one subject.
    Input:
        path_data: path of EEG data (.mat)
        stft_para: parameters for DE and PSD
        save_path: path to save feature (.mat), if None, not save
    '''
    # data_EEG: n_channels * n_times
    EEG_data = loadmat(os.path.join(path_data, 'EEG_videos.mat'))
    EEG_feature = {}
    
    for vi in EEG_data.keys():
        if 'video_' in vi:
            EEG_vi = EEG_data[vi].reshape(EEG_data[vi].shape[0], -1, stft_para['window']*stft_para['fs']).transpose([1,0,2])
            print('  [info] Video %s: %s' % (vi, EEG_vi.shape), end=' ')
            EEG_feature_vi = []
            for d in EEG_vi:
                psd, de = DE_PSD(d, stft_para)
                EEG_feature_vi.append(de)
            EEG_feature_vi = np.array(EEG_feature_vi)
            print('-> Feature: %s' % (EEG_feature_vi.shape,))
            
            EEG_feature[vi] = EEG_feature_vi
            
    if save_path is not None:
        feature_mat_path = os.path.join(save_path, 'EEG_videos_feature.mat')
        savemat(feature_mat_path, EEG_feature)
        print('[info] Save feature to: %s' % (feature_mat_path))

# %% [markdown]
# ### Perform feature extraction

# %%
for si in sub_list:
    print('Processing EEG data of subject ID.[%s]...' % si)
    path_data_si = os.path.join(path_data, si)
    path_feature_si = os.path.join(path_feature, si)
    if not os.path.exists(path_feature_si):
        os.makedirs(path_feature_si)
    
    feature_EEG_sub(path_data_si, stft_para, save_path=path_feature_si)
# Out:
# Processing EEG data of subject ID.[1]...
#   [info] Video video_1: (134, 64, 1000) -> Feature: (134, 64, 5)
#   [info] Video video_2: (137, 64, 1000) -> Feature: (137, 64, 5)
#   [info] Video video_3: (90, 64, 1000) -> Feature: (90, 64, 5)
#   [info] Video video_4: (79, 64, 1000) -> Feature: (79, 64, 5)
#   [info] Video video_5: (135, 64, 1000) -> Feature: (135, 64, 5)
#   [info] Video video_6: (93, 64, 1000) -> Feature: (93, 64, 5)
#   [info] Video video_7: (122, 64, 1000) -> Feature: (122, 64, 5)
#   [info] Video video_8: (107, 64, 1000) -> Feature: (107, 64, 5)
#   [info] Video video_9: (70, 64, 1000) -> Feature: (70, 64, 5)
#   [info] Video video_10: (60, 64, 1000) -> Feature: (60, 64, 5)
#   [info] Video video_11: (61, 64, 1000) -> Feature: (61, 64, 5)
#   [info] Video video_12: (63, 64, 1000) -> Feature: (63, 64, 5)
#   [info] Video video_13: (111, 64, 1000) -> Feature: (111, 64, 5)
#   [info] Video video_14: (103, 64, 1000) -> Feature: (103, 64, 5)
#   [info] Video video_15: (170, 64, 1000) -> Feature: (170, 64, 5)
# [info] Save feature to: ./REFED-dataset/features\1\EEG_videos_feature.mat
# Processing EEG data of subject ID.[10]...
#   [info] Video video_1: (134, 64, 1000) -> Feature: (134, 64, 5)
#   [info] Video video_2: (137, 64, 1000) -> Feature: (137, 64, 5)
#   [info] Video video_3: (90, 64, 1000) -> Feature: (90, 64, 5)
#   [info] Video video_4: (79, 64, 1000) -> Feature: (79, 64, 5)
#   [info] Video video_5: (135, 64, 1000) -> Feature: (135, 64, 5)
#   [info] Video video_6: (93, 64, 1000) -> Feature: (93, 64, 5)
#   [info] Video video_7: (122, 64, 1000) -> Feature: (122, 64, 5)
#   [info] Video video_8: (107, 64, 1000) -> Feature: (107, 64, 5)
#   [info] Video video_9: (70, 64, 1000) -> Feature: (70, 64, 5)
#   [info] Video video_10: (60, 64, 1000) -> Feature: (60, 64, 5)
#   [info] Video video_11: (61, 64, 1000) -> Feature: (61, 64, 5)
#   [info] Video video_12: (63, 64, 1000) -> Feature: (63, 64, 5)
#   [info] Video video_13: (111, 64, 1000) -> Feature: (111, 64, 5)
#   [info] Video video_14: (103, 64, 1000) -> Feature: (103, 64, 5)
#   [info] Video video_15: (170, 64, 1000) -> Feature: (170, 64, 5)
# [info] Save feature to: ./REFED-dataset/features\10\EEG_videos_feature.mat
# Processing EEG data of subject ID.[11]...
#   [info] Video video_1: (134, 64, 1000) -> Feature: (134, 64, 5)
#   [info] Video video_2: (137, 64, 1000) -> Feature: (137, 64, 5)
#   [info] Video video_3: (90, 64, 1000) -> Feature: (90, 64, 5)
#   [info] Video video_4: (79, 64, 1000) -> Feature: (79, 64, 5)
#   [info] Video video_5: (135, 64, 1000) -> Feature: (135, 64, 5)
#   [info] Video video_6: (93, 64, 1000) -> Feature: (93, 64, 5)
#   [info] Video video_7: (122, 64, 1000) -> Feature: (122, 64, 5)
#   [info] Video video_8: (107, 64, 1000) -> Feature: (107, 64, 5)
#   [info] Video video_9: (70, 64, 1000) -> Feature: (70, 64, 5)
#   [info] Video video_10: (60, 64, 1000) -> Feature: (60, 64, 5)
#   [info] Video video_11: (61, 64, 1000) -> Feature: (61, 64, 5)
#   [info] Video video_12: (63, 64, 1000) -> Feature: (63, 64, 5)
#   [info] Video video_13: (111, 64, 1000) -> Feature: (111, 64, 5)
#   [info] Video video_14: (103, 64, 1000) -> Feature: (103, 64, 5)
#   [info] Video video_15: (170, 64, 1000) -> Feature: (170, 64, 5)
# [info] Save feature to: ./REFED-dataset/features\11\EEG_videos_feature.mat
# Processing EEG data of subject ID.[12]...
#   [info] Video video_1: (134, 64, 1000) -> Feature: (134, 64, 5)
#   [info] Video video_2: (137, 64, 1000) -> Feature: (137, 64, 5)
#   [info] Video video_3: (90, 64, 1000) -> Feature: (90, 64, 5)
#   [info] Video video_4: (79, 64, 1000) -> Feature: (79, 64, 5)
#   [info] Video video_5: (135, 64, 1000) -> Feature: (135, 64, 5)
#   [info] Video video_6: (93, 64, 1000) -> Feature: (93, 64, 5)
#   [info] Video video_7: (122, 64, 1000) -> Feature: (122, 64, 5)
#   [info] Video video_8: (107, 64, 1000) -> Feature: (107, 64, 5)
#   [info] Video video_9: (70, 64, 1000) -> Feature: (70, 64, 5)
#   [info] Video video_10: (60, 64, 1000) -> Feature: (60, 64, 5)
#   [info] Video video_11: (61, 64, 1000) -> Feature: (61, 64, 5)
#   [info] Video video_12: (63, 64, 1000) -> Feature: (63, 64, 5)
#   [info] Video video_13: (111, 64, 1000) -> Feature: (111, 64, 5)
#   [info] Video video_14: (103, 64, 1000) -> Feature: (103, 64, 5)
#   [info] Video video_15: (170, 64, 1000) -> Feature: (170, 64, 5)
# [info] Save feature to: ./REFED-dataset/features\12\EEG_videos_feature.mat
# Processing EEG data of subject ID.[13]...
#   [info] Video video_1: (134, 64, 1000) -> Feature: (134, 64, 5)
#   [info] Video video_2: (137, 64, 1000) -> Feature: (137, 64, 5)
#   [info] Video video_3: (90, 64, 1000) -> Feature: (90, 64, 5)
#   [info] Video video_4: (79, 64, 1000) -> Feature: (79, 64, 5)
#   [info] Video video_5: (135, 64, 1000) -> Feature: (135, 64, 5)
#   [info] Video video_6: (93, 64, 1000) -> Feature: (93, 64, 5)
#   [info] Video video_7: (122, 64, 1000) -> Feature: (122, 64, 5)
#   [info] Video video_8: (107, 64, 1000) -> Feature: (107, 64, 5)
#   [info] Video video_9: (70, 64, 1000) -> Feature: (70, 64, 5)
#   [info] Video video_10: (60, 64, 1000) -> Feature: (60, 64, 5)
#   [info] Video video_11: (61, 64, 1000) -> Feature: (61, 64, 5)
#   [info] Video video_12: (63, 64, 1000) -> Feature: (63, 64, 5)
#   [info] Video video_13: (111, 64, 1000) -> Feature: (111, 64, 5)
#   [info] Video video_14: (103, 64, 1000) -> Feature: (103, 64, 5)
#   [info] Video video_15: (170, 64, 1000) -> Feature: (170, 64, 5)
# [info] Save feature to: ./REFED-dataset/features\13\EEG_videos_feature.mat
# Processing EEG data of subject ID.[14]...
#   [info] Video video_1: (134, 64, 1000) -> Feature: (134, 64, 5)
#   [info] Video video_2: (137, 64, 1000) -> Feature: (137, 64, 5)
#   [info] Video video_3: (90, 64, 1000) -> Feature: (90, 64, 5)
#   [info] Video video_4: (79, 64, 1000) -> Feature: (79, 64, 5)
#   [info] Video video_5: (135, 64, 1000) -> Feature: (135, 64, 5)
#   [info] Video video_6: (93, 64, 1000) -> Feature: (93, 64, 5)
#   [info] Video video_7: (122, 64, 1000) -> Feature: (122, 64, 5)
#   [info] Video video_8: (107, 64, 1000) -> Feature: (107, 64, 5)
#   [info] Video video_9: (70, 64, 1000) -> Feature: (70, 64, 5)
#   [info] Video video_10: (60, 64, 1000) -> Feature: (60, 64, 5)
#   [info] Video video_11: (61, 64, 1000) -> Feature: (61, 64, 5)
#   [info] Video video_12: (63, 64, 1000) -> Feature: (63, 64, 5)
#   [info] Video video_13: (111, 64, 1000) -> Feature: (111, 64, 5)
#   [info] Video video_14: (103, 64, 1000) -> Feature: (103, 64, 5)
#   [info] Video video_15: (170, 64, 1000) -> Feature: (170, 64, 5)
# [info] Save feature to: ./REFED-dataset/features\14\EEG_videos_feature.mat
# Processing EEG data of subject ID.[15]...
#   [info] Video video_1: (134, 64, 1000) -> Feature: (134, 64, 5)
#   [info] Video video_2: (137, 64, 1000) -> Feature: (137, 64, 5)
#   [info] Video video_3: (90, 64, 1000) -> Feature: (90, 64, 5)
#   [info] Video video_4: (79, 64, 1000) -> Feature: (79, 64, 5)
#   [info] Video video_5: (135, 64, 1000) -> Feature: (135, 64, 5)
#   [info] Video video_6: (93, 64, 1000) -> Feature: (93, 64, 5)
#   [info] Video video_7: (122, 64, 1000) -> Feature: (122, 64, 5)
#   [info] Video video_8: (107, 64, 1000) -> Feature: (107, 64, 5)
#   [info] Video video_9: (70, 64, 1000) -> Feature: (70, 64, 5)
#   [info] Video video_10: (60, 64, 1000) -> Feature: (60, 64, 5)
#   [info] Video video_11: (61, 64, 1000) -> Feature: (61, 64, 5)
#   [info] Video video_12: (63, 64, 1000) -> Feature: (63, 64, 5)
#   [info] Video video_13: (111, 64, 1000) -> Feature: (111, 64, 5)
#   [info] Video video_14: (103, 64, 1000) -> Feature: (103, 64, 5)
#   [info] Video video_15: (170, 64, 1000) -> Feature: (170, 64, 5)
# [info] Save feature to: ./REFED-dataset/features\15\EEG_videos_feature.mat
# Processing EEG data of subject ID.[16]...
#   [info] Video video_1: (134, 64, 1000) -> Feature: (134, 64, 5)
#   [info] Video video_2: (137, 64, 1000) -> Feature: (137, 64, 5)
#   [info] Video video_3: (90, 64, 1000) -> Feature: (90, 64, 5)
#   [info] Video video_4: (79, 64, 1000) -> Feature: (79, 64, 5)
#   [info] Video video_5: (135, 64, 1000) -> Feature: (135, 64, 5)
#   [info] Video video_6: (93, 64, 1000) -> Feature: (93, 64, 5)
#   [info] Video video_7: (122, 64, 1000) -> Feature: (122, 64, 5)
#   [info] Video video_8: (107, 64, 1000) -> Feature: (107, 64, 5)
#   [info] Video video_9: (70, 64, 1000) -> Feature: (70, 64, 5)
#   [info] Video video_10: (60, 64, 1000) -> Feature: (60, 64, 5)
#   [info] Video video_11: (61, 64, 1000) -> Feature: (61, 64, 5)
#   [info] Video video_12: (63, 64, 1000) -> Feature: (63, 64, 5)
#   [info] Video video_13: (111, 64, 1000) -> Feature: (111, 64, 5)
#   [info] Video video_14: (103, 64, 1000) -> Feature: (103, 64, 5)
#   [info] Video video_15: (170, 64, 1000) -> Feature: (170, 64, 5)
# [info] Save feature to: ./REFED-dataset/features\16\EEG_videos_feature.mat
# Processing EEG data of subject ID.[17]...
#   [info] Video video_1: (134, 64, 1000) -> Feature: (134, 64, 5)
#   [info] Video video_2: (137, 64, 1000) -> Feature: (137, 64, 5)
#   [info] Video video_3: (90, 64, 1000) -> Feature: (90, 64, 5)
#   [info] Video video_4: (79, 64, 1000) -> Feature: (79, 64, 5)
#   [info] Video video_5: (135, 64, 1000) -> Feature: (135, 64, 5)
#   [info] Video video_6: (93, 64, 1000) -> Feature: (93, 64, 5)
#   [info] Video video_7: (122, 64, 1000) -> Feature: (122, 64, 5)
#   [info] Video video_8: (107, 64, 1000) -> Feature: (107, 64, 5)
#   [info] Video video_9: (70, 64, 1000) -> Feature: (70, 64, 5)
#   [info] Video video_10: (60, 64, 1000) -> Feature: (60, 64, 5)
#   [info] Video video_11: (61, 64, 1000) -> Feature: (61, 64, 5)
#   [info] Video video_12: (63, 64, 1000) -> Feature: (63, 64, 5)
#   [info] Video video_13: (111, 64, 1000) -> Feature: (111, 64, 5)
#   [info] Video video_14: (103, 64, 1000) -> Feature: (103, 64, 5)
#   [info] Video video_15: (170, 64, 1000) -> Feature: (170, 64, 5)
# [info] Save feature to: ./REFED-dataset/features\17\EEG_videos_feature.mat
# Processing EEG data of subject ID.[18]...
#   [info] Video video_1: (134, 64, 1000) -> Feature: (134, 64, 5)
#   [info] Video video_2: (137, 64, 1000) -> Feature: (137, 64, 5)
#   [info] Video video_3: (90, 64, 1000) -> Feature: (90, 64, 5)
#   [info] Video video_4: (79, 64, 1000) -> Feature: (79, 64, 5)
#   [info] Video video_5: (135, 64, 1000) -> Feature: (135, 64, 5)
#   [info] Video video_6: (93, 64, 1000) -> Feature: (93, 64, 5)
#   [info] Video video_7: (122, 64, 1000) -> Feature: (122, 64, 5)
#   [info] Video video_8: (107, 64, 1000) -> Feature: (107, 64, 5)
#   [info] Video video_9: (70, 64, 1000) -> Feature: (70, 64, 5)
#   [info] Video video_10: (60, 64, 1000) -> Feature: (60, 64, 5)
#   [info] Video video_11: (61, 64, 1000) -> Feature: (61, 64, 5)
#   [info] Video video_12: (63, 64, 1000) -> Feature: (63, 64, 5)
#   [info] Video video_13: (111, 64, 1000) -> Feature: (111, 64, 5)
#   [info] Video video_14: (103, 64, 1000) -> Feature: (103, 64, 5)
#   [info] Video video_15: (170, 64, 1000) -> Feature: (170, 64, 5)
# [info] Save feature to: ./REFED-dataset/features\18\EEG_videos_feature.mat
# Processing EEG data of subject ID.[19]...
#   [info] Video video_1: (134, 64, 1000) -> Feature: (134, 64, 5)
#   [info] Video video_2: (137, 64, 1000) -> Feature: (137, 64, 5)
#   [info] Video video_3: (90, 64, 1000) -> Feature: (90, 64, 5)
#   [info] Video video_4: (79, 64, 1000) -> Feature: (79, 64, 5)
#   [info] Video video_5: (135, 64, 1000) -> Feature: (135, 64, 5)
#   [info] Video video_6: (93, 64, 1000) -> Feature: (93, 64, 5)
#   [info] Video video_7: (122, 64, 1000) -> Feature: (122, 64, 5)
#   [info] Video video_8: (107, 64, 1000) -> Feature: (107, 64, 5)
#   [info] Video video_9: (70, 64, 1000) -> Feature: (70, 64, 5)
#   [info] Video video_10: (60, 64, 1000) -> Feature: (60, 64, 5)
#   [info] Video video_11: (61, 64, 1000) -> Feature: (61, 64, 5)
#   [info] Video video_12: (63, 64, 1000) -> Feature: (63, 64, 5)
#   [info] Video video_13: (111, 64, 1000) -> Feature: (111, 64, 5)
#   [info] Video video_14: (103, 64, 1000) -> Feature: (103, 64, 5)
#   [info] Video video_15: (170, 64, 1000) -> Feature: (170, 64, 5)
# [info] Save feature to: ./REFED-dataset/features\19\EEG_videos_feature.mat
# Processing EEG data of subject ID.[2]...
#   [info] Video video_1: (134, 64, 1000) -> Feature: (134, 64, 5)
#   [info] Video video_2: (137, 64, 1000) -> Feature: (137, 64, 5)
#   [info] Video video_3: (90, 64, 1000) -> Feature: (90, 64, 5)
#   [info] Video video_4: (79, 64, 1000) -> Feature: (79, 64, 5)
#   [info] Video video_5: (135, 64, 1000) -> Feature: (135, 64, 5)
#   [info] Video video_6: (93, 64, 1000) -> Feature: (93, 64, 5)
#   [info] Video video_7: (122, 64, 1000) -> Feature: (122, 64, 5)
#   [info] Video video_8: (107, 64, 1000) -> Feature: (107, 64, 5)
#   [info] Video video_9: (70, 64, 1000) -> Feature: (70, 64, 5)
#   [info] Video video_10: (60, 64, 1000) -> Feature: (60, 64, 5)
#   [info] Video video_11: (61, 64, 1000) -> Feature: (61, 64, 5)
#   [info] Video video_12: (63, 64, 1000) -> Feature: (63, 64, 5)
#   [info] Video video_13: (111, 64, 1000) -> Feature: (111, 64, 5)
#   [info] Video video_14: (103, 64, 1000) -> Feature: (103, 64, 5)
#   [info] Video video_15: (170, 64, 1000) -> Feature: (170, 64, 5)
# [info] Save feature to: ./REFED-dataset/features\2\EEG_videos_feature.mat
# Processing EEG data of subject ID.[20]...
#   [info] Video video_1: (134, 64, 1000) -> Feature: (134, 64, 5)
#   [info] Video video_2: (137, 64, 1000) -> Feature: (137, 64, 5)
#   [info] Video video_3: (90, 64, 1000) -> Feature: (90, 64, 5)
#   [info] Video video_4: (79, 64, 1000) -> Feature: (79, 64, 5)
#   [info] Video video_5: (135, 64, 1000) -> Feature: (135, 64, 5)
#   [info] Video video_6: (93, 64, 1000) -> Feature: (93, 64, 5)
#   [info] Video video_7: (122, 64, 1000) -> Feature: (122, 64, 5)
#   [info] Video video_8: (107, 64, 1000) -> Feature: (107, 64, 5)
#   [info] Video video_9: (70, 64, 1000) -> Feature: (70, 64, 5)
#   [info] Video video_10: (60, 64, 1000) -> Feature: (60, 64, 5)
#   [info] Video video_11: (61, 64, 1000) -> Feature: (61, 64, 5)
#   [info] Video video_12: (63, 64, 1000) -> Feature: (63, 64, 5)
#   [info] Video video_13: (111, 64, 1000) -> Feature: (111, 64, 5)
#   [info] Video video_14: (103, 64, 1000) -> Feature: (103, 64, 5)
#   [info] Video video_15: (170, 64, 1000) -> Feature: (170, 64, 5)
# [info] Save feature to: ./REFED-dataset/features\20\EEG_videos_feature.mat
# Processing EEG data of subject ID.[21]...
#   [info] Video video_1: (134, 64, 1000) -> Feature: (134, 64, 5)
#   [info] Video video_2: (137, 64, 1000) -> Feature: (137, 64, 5)
#   [info] Video video_3: (90, 64, 1000) -> Feature: (90, 64, 5)
#   [info] Video video_4: (79, 64, 1000) -> Feature: (79, 64, 5)
#   [info] Video video_5: (135, 64, 1000) -> Feature: (135, 64, 5)
#   [info] Video video_6: (93, 64, 1000) -> Feature: (93, 64, 5)
#   [info] Video video_7: (122, 64, 1000) -> Feature: (122, 64, 5)
#   [info] Video video_8: (107, 64, 1000) -> Feature: (107, 64, 5)
#   [info] Video video_9: (70, 64, 1000) -> Feature: (70, 64, 5)
#   [info] Video video_10: (60, 64, 1000) -> Feature: (60, 64, 5)
#   [info] Video video_11: (61, 64, 1000) -> Feature: (61, 64, 5)
#   [info] Video video_12: (63, 64, 1000) -> Feature: (63, 64, 5)
#   [info] Video video_13: (111, 64, 1000) -> Feature: (111, 64, 5)
#   [info] Video video_14: (103, 64, 1000) -> Feature: (103, 64, 5)
#   [info] Video video_15: (170, 64, 1000) -> Feature: (170, 64, 5)
# [info] Save feature to: ./REFED-dataset/features\21\EEG_videos_feature.mat
# Processing EEG data of subject ID.[22]...
#   [info] Video video_1: (134, 64, 1000) -> Feature: (134, 64, 5)
#   [info] Video video_2: (137, 64, 1000) -> Feature: (137, 64, 5)
#   [info] Video video_3: (90, 64, 1000) -> Feature: (90, 64, 5)
#   [info] Video video_4: (79, 64, 1000) -> Feature: (79, 64, 5)
#   [info] Video video_5: (135, 64, 1000) -> Feature: (135, 64, 5)
#   [info] Video video_6: (93, 64, 1000) -> Feature: (93, 64, 5)
#   [info] Video video_7: (122, 64, 1000) -> Feature: (122, 64, 5)
#   [info] Video video_8: (107, 64, 1000) -> Feature: (107, 64, 5)
#   [info] Video video_9: (70, 64, 1000) -> Feature: (70, 64, 5)
#   [info] Video video_10: (60, 64, 1000) -> Feature: (60, 64, 5)
#   [info] Video video_11: (61, 64, 1000) -> Feature: (61, 64, 5)
#   [info] Video video_12: (63, 64, 1000) -> Feature: (63, 64, 5)
#   [info] Video video_13: (111, 64, 1000) -> Feature: (111, 64, 5)
#   [info] Video video_14: (103, 64, 1000) -> Feature: (103, 64, 5)
#   [info] Video video_15: (170, 64, 1000) -> Feature: (170, 64, 5)
# [info] Save feature to: ./REFED-dataset/features\22\EEG_videos_feature.mat
# Processing EEG data of subject ID.[23]...
#   [info] Video video_1: (134, 64, 1000) -> Feature: (134, 64, 5)
#   [info] Video video_2: (137, 64, 1000) -> Feature: (137, 64, 5)
#   [info] Video video_3: (90, 64, 1000) -> Feature: (90, 64, 5)
#   [info] Video video_4: (79, 64, 1000) -> Feature: (79, 64, 5)
#   [info] Video video_5: (135, 64, 1000) -> Feature: (135, 64, 5)
#   [info] Video video_6: (93, 64, 1000) -> Feature: (93, 64, 5)
#   [info] Video video_7: (122, 64, 1000) -> Feature: (122, 64, 5)
#   [info] Video video_8: (107, 64, 1000) -> Feature: (107, 64, 5)
#   [info] Video video_9: (70, 64, 1000) -> Feature: (70, 64, 5)
#   [info] Video video_10: (60, 64, 1000) -> Feature: (60, 64, 5)
#   [info] Video video_11: (61, 64, 1000) -> Feature: (61, 64, 5)
#   [info] Video video_12: (63, 64, 1000) -> Feature: (63, 64, 5)
#   [info] Video video_13: (111, 64, 1000) -> Feature: (111, 64, 5)
#   [info] Video video_14: (103, 64, 1000) -> Feature: (103, 64, 5)
#   [info] Video video_15: (170, 64, 1000) -> Feature: (170, 64, 5)
# [info] Save feature to: ./REFED-dataset/features\23\EEG_videos_feature.mat
# Processing EEG data of subject ID.[24]...
#   [info] Video video_1: (134, 64, 1000) -> Feature: (134, 64, 5)
#   [info] Video video_2: (137, 64, 1000) -> Feature: (137, 64, 5)
#   [info] Video video_3: (90, 64, 1000) -> Feature: (90, 64, 5)
#   [info] Video video_4: (79, 64, 1000) -> Feature: (79, 64, 5)
#   [info] Video video_5: (135, 64, 1000) -> Feature: (135, 64, 5)
#   [info] Video video_6: (93, 64, 1000) -> Feature: (93, 64, 5)
#   [info] Video video_7: (122, 64, 1000) -> Feature: (122, 64, 5)
#   [info] Video video_8: (107, 64, 1000) -> Feature: (107, 64, 5)
#   [info] Video video_9: (70, 64, 1000) -> Feature: (70, 64, 5)
#   [info] Video video_10: (60, 64, 1000) -> Feature: (60, 64, 5)
#   [info] Video video_11: (61, 64, 1000) -> Feature: (61, 64, 5)
#   [info] Video video_12: (63, 64, 1000) -> Feature: (63, 64, 5)
#   [info] Video video_13: (111, 64, 1000) -> Feature: (111, 64, 5)
#   [info] Video video_14: (103, 64, 1000) -> Feature: (103, 64, 5)
#   [info] Video video_15: (170, 64, 1000) -> Feature: (170, 64, 5)
# [info] Save feature to: ./REFED-dataset/features\24\EEG_videos_feature.mat
# Processing EEG data of subject ID.[25]...
#   [info] Video video_1: (134, 64, 1000) -> Feature: (134, 64, 5)
#   [info] Video video_2: (137, 64, 1000) -> Feature: (137, 64, 5)
#   [info] Video video_3: (90, 64, 1000) -> Feature: (90, 64, 5)
#   [info] Video video_4: (79, 64, 1000) -> Feature: (79, 64, 5)
#   [info] Video video_5: (135, 64, 1000) -> Feature: (135, 64, 5)
#   [info] Video video_6: (93, 64, 1000) -> Feature: (93, 64, 5)
#   [info] Video video_7: (122, 64, 1000) -> Feature: (122, 64, 5)
#   [info] Video video_8: (107, 64, 1000) -> Feature: (107, 64, 5)
#   [info] Video video_9: (70, 64, 1000) -> Feature: (70, 64, 5)
#   [info] Video video_10: (60, 64, 1000) -> Feature: (60, 64, 5)
#   [info] Video video_11: (61, 64, 1000) -> Feature: (61, 64, 5)
#   [info] Video video_12: (63, 64, 1000) -> Feature: (63, 64, 5)
#   [info] Video video_13: (111, 64, 1000) -> Feature: (111, 64, 5)
#   [info] Video video_14: (103, 64, 1000) -> Feature: (103, 64, 5)
#   [info] Video video_15: (170, 64, 1000) -> Feature: (170, 64, 5)
# [info] Save feature to: ./REFED-dataset/features\25\EEG_videos_feature.mat
# Processing EEG data of subject ID.[26]...
#   [info] Video video_1: (134, 64, 1000) -> Feature: (134, 64, 5)
#   [info] Video video_2: (137, 64, 1000) -> Feature: (137, 64, 5)
#   [info] Video video_3: (90, 64, 1000) -> Feature: (90, 64, 5)
#   [info] Video video_4: (79, 64, 1000) -> Feature: (79, 64, 5)
#   [info] Video video_5: (135, 64, 1000) -> Feature: (135, 64, 5)
#   [info] Video video_6: (93, 64, 1000) -> Feature: (93, 64, 5)
#   [info] Video video_7: (122, 64, 1000) -> Feature: (122, 64, 5)
#   [info] Video video_8: (107, 64, 1000) -> Feature: (107, 64, 5)
#   [info] Video video_9: (70, 64, 1000) -> Feature: (70, 64, 5)
#   [info] Video video_10: (60, 64, 1000) -> Feature: (60, 64, 5)
#   [info] Video video_11: (61, 64, 1000) -> Feature: (61, 64, 5)
#   [info] Video video_12: (63, 64, 1000) -> Feature: (63, 64, 5)
#   [info] Video video_13: (111, 64, 1000) -> Feature: (111, 64, 5)
#   [info] Video video_14: (103, 64, 1000) -> Feature: (103, 64, 5)
#   [info] Video video_15: (170, 64, 1000) -> Feature: (170, 64, 5)
# [info] Save feature to: ./REFED-dataset/features\26\EEG_videos_feature.mat
# Processing EEG data of subject ID.[27]...
#   [info] Video video_1: (134, 64, 1000) -> Feature: (134, 64, 5)
#   [info] Video video_2: (137, 64, 1000) -> Feature: (137, 64, 5)
#   [info] Video video_3: (90, 64, 1000) -> Feature: (90, 64, 5)
#   [info] Video video_4: (79, 64, 1000) -> Feature: (79, 64, 5)
#   [info] Video video_5: (135, 64, 1000) -> Feature: (135, 64, 5)
#   [info] Video video_6: (93, 64, 1000) -> Feature: (93, 64, 5)
#   [info] Video video_7: (122, 64, 1000) -> Feature: (122, 64, 5)
#   [info] Video video_8: (107, 64, 1000) -> Feature: (107, 64, 5)
#   [info] Video video_9: (70, 64, 1000) -> Feature: (70, 64, 5)
#   [info] Video video_10: (60, 64, 1000) -> Feature: (60, 64, 5)
#   [info] Video video_11: (61, 64, 1000) -> Feature: (61, 64, 5)
#   [info] Video video_12: (63, 64, 1000) -> Feature: (63, 64, 5)
#   [info] Video video_13: (111, 64, 1000) -> Feature: (111, 64, 5)
#   [info] Video video_14: (103, 64, 1000) -> Feature: (103, 64, 5)
#   [info] Video video_15: (170, 64, 1000) -> Feature: (170, 64, 5)
# [info] Save feature to: ./REFED-dataset/features\27\EEG_videos_feature.mat
# Processing EEG data of subject ID.[28]...
#   [info] Video video_1: (134, 64, 1000) -> Feature: (134, 64, 5)
#   [info] Video video_2: (137, 64, 1000) -> Feature: (137, 64, 5)
#   [info] Video video_3: (90, 64, 1000) -> Feature: (90, 64, 5)
#   [info] Video video_4: (79, 64, 1000) -> Feature: (79, 64, 5)
#   [info] Video video_5: (135, 64, 1000) -> Feature: (135, 64, 5)
#   [info] Video video_6: (93, 64, 1000) -> Feature: (93, 64, 5)
#   [info] Video video_7: (122, 64, 1000) -> Feature: (122, 64, 5)
#   [info] Video video_8: (107, 64, 1000) -> Feature: (107, 64, 5)
#   [info] Video video_9: (70, 64, 1000) -> Feature: (70, 64, 5)
#   [info] Video video_10: (60, 64, 1000) -> Feature: (60, 64, 5)
#   [info] Video video_11: (61, 64, 1000) -> Feature: (61, 64, 5)
#   [info] Video video_12: (63, 64, 1000) -> Feature: (63, 64, 5)
#   [info] Video video_13: (111, 64, 1000) -> Feature: (111, 64, 5)
#   [info] Video video_14: (103, 64, 1000) -> Feature: (103, 64, 5)
#   [info] Video video_15: (170, 64, 1000) -> Feature: (170, 64, 5)
# [info] Save feature to: ./REFED-dataset/features\28\EEG_videos_feature.mat
# Processing EEG data of subject ID.[29]...
#   [info] Video video_1: (134, 64, 1000) -> Feature: (134, 64, 5)
#   [info] Video video_2: (137, 64, 1000) -> Feature: (137, 64, 5)
#   [info] Video video_3: (90, 64, 1000) -> Feature: (90, 64, 5)
#   [info] Video video_4: (79, 64, 1000) -> Feature: (79, 64, 5)
#   [info] Video video_5: (135, 64, 1000) -> Feature: (135, 64, 5)
#   [info] Video video_6: (93, 64, 1000) -> Feature: (93, 64, 5)
#   [info] Video video_7: (122, 64, 1000) -> Feature: (122, 64, 5)
#   [info] Video video_8: (107, 64, 1000) -> Feature: (107, 64, 5)
#   [info] Video video_9: (70, 64, 1000) -> Feature: (70, 64, 5)
#   [info] Video video_10: (60, 64, 1000) -> Feature: (60, 64, 5)
#   [info] Video video_11: (61, 64, 1000) -> Feature: (61, 64, 5)
#   [info] Video video_12: (63, 64, 1000) -> Feature: (63, 64, 5)
#   [info] Video video_13: (111, 64, 1000) -> Feature: (111, 64, 5)
#   [info] Video video_14: (103, 64, 1000) -> Feature: (103, 64, 5)
#   [info] Video video_15: (170, 64, 1000) -> Feature: (170, 64, 5)
# [info] Save feature to: ./REFED-dataset/features\29\EEG_videos_feature.mat
# Processing EEG data of subject ID.[3]...
#   [info] Video video_1: (134, 64, 1000) -> Feature: (134, 64, 5)
#   [info] Video video_2: (137, 64, 1000) -> Feature: (137, 64, 5)
#   [info] Video video_3: (90, 64, 1000) -> Feature: (90, 64, 5)
#   [info] Video video_4: (79, 64, 1000) -> Feature: (79, 64, 5)
#   [info] Video video_5: (135, 64, 1000) -> Feature: (135, 64, 5)
#   [info] Video video_6: (93, 64, 1000) -> Feature: (93, 64, 5)
#   [info] Video video_7: (122, 64, 1000) -> Feature: (122, 64, 5)
#   [info] Video video_8: (107, 64, 1000) -> Feature: (107, 64, 5)
#   [info] Video video_9: (70, 64, 1000) -> Feature: (70, 64, 5)
#   [info] Video video_10: (60, 64, 1000) -> Feature: (60, 64, 5)
#   [info] Video video_11: (61, 64, 1000) -> Feature: (61, 64, 5)
#   [info] Video video_12: (63, 64, 1000) -> Feature: (63, 64, 5)
#   [info] Video video_13: (111, 64, 1000) -> Feature: (111, 64, 5)
#   [info] Video video_14: (103, 64, 1000) -> Feature: (103, 64, 5)
#   [info] Video video_15: (170, 64, 1000) -> Feature: (170, 64, 5)
# [info] Save feature to: ./REFED-dataset/features\3\EEG_videos_feature.mat
# Processing EEG data of subject ID.[30]...
#   [info] Video video_1: (134, 64, 1000) -> Feature: (134, 64, 5)
#   [info] Video video_2: (137, 64, 1000) -> Feature: (137, 64, 5)
#   [info] Video video_3: (90, 64, 1000) -> Feature: (90, 64, 5)
#   [info] Video video_4: (79, 64, 1000) -> Feature: (79, 64, 5)
#   [info] Video video_5: (135, 64, 1000) -> Feature: (135, 64, 5)
#   [info] Video video_6: (93, 64, 1000) -> Feature: (93, 64, 5)
#   [info] Video video_7: (122, 64, 1000) -> Feature: (122, 64, 5)
#   [info] Video video_8: (107, 64, 1000) -> Feature: (107, 64, 5)
#   [info] Video video_9: (70, 64, 1000) -> Feature: (70, 64, 5)
#   [info] Video video_10: (60, 64, 1000) -> Feature: (60, 64, 5)
#   [info] Video video_11: (61, 64, 1000) -> Feature: (61, 64, 5)
#   [info] Video video_12: (63, 64, 1000) -> Feature: (63, 64, 5)
#   [info] Video video_13: (111, 64, 1000) -> Feature: (111, 64, 5)
#   [info] Video video_14: (103, 64, 1000) -> Feature: (103, 64, 5)
#   [info] Video video_15: (170, 64, 1000) -> Feature: (170, 64, 5)
# [info] Save feature to: ./REFED-dataset/features\30\EEG_videos_feature.mat
# Processing EEG data of subject ID.[31]...
#   [info] Video video_1: (134, 64, 1000) -> Feature: (134, 64, 5)
#   [info] Video video_2: (137, 64, 1000) -> Feature: (137, 64, 5)
#   [info] Video video_3: (90, 64, 1000) -> Feature: (90, 64, 5)
#   [info] Video video_4: (79, 64, 1000) -> Feature: (79, 64, 5)
#   [info] Video video_5: (135, 64, 1000) -> Feature: (135, 64, 5)
#   [info] Video video_6: (93, 64, 1000) -> Feature: (93, 64, 5)
#   [info] Video video_7: (122, 64, 1000) -> Feature: (122, 64, 5)
#   [info] Video video_8: (107, 64, 1000) -> Feature: (107, 64, 5)
#   [info] Video video_9: (70, 64, 1000) -> Feature: (70, 64, 5)
#   [info] Video video_10: (60, 64, 1000) -> Feature: (60, 64, 5)
#   [info] Video video_11: (61, 64, 1000) -> Feature: (61, 64, 5)
#   [info] Video video_12: (63, 64, 1000) -> Feature: (63, 64, 5)
#   [info] Video video_13: (111, 64, 1000) -> Feature: (111, 64, 5)
#   [info] Video video_14: (103, 64, 1000) -> Feature: (103, 64, 5)
#   [info] Video video_15: (170, 64, 1000) -> Feature: (170, 64, 5)
# [info] Save feature to: ./REFED-dataset/features\31\EEG_videos_feature.mat
# Processing EEG data of subject ID.[32]...
#   [info] Video video_1: (134, 64, 1000) -> Feature: (134, 64, 5)
#   [info] Video video_2: (137, 64, 1000) -> Feature: (137, 64, 5)
#   [info] Video video_3: (90, 64, 1000) -> Feature: (90, 64, 5)
#   [info] Video video_4: (79, 64, 1000) -> Feature: (79, 64, 5)
#   [info] Video video_5: (135, 64, 1000) -> Feature: (135, 64, 5)
#   [info] Video video_6: (93, 64, 1000) -> Feature: (93, 64, 5)
#   [info] Video video_7: (122, 64, 1000) -> Feature: (122, 64, 5)
#   [info] Video video_8: (107, 64, 1000) -> Feature: (107, 64, 5)
#   [info] Video video_9: (70, 64, 1000) -> Feature: (70, 64, 5)
#   [info] Video video_10: (60, 64, 1000) -> Feature: (60, 64, 5)
#   [info] Video video_11: (61, 64, 1000) -> Feature: (61, 64, 5)
#   [info] Video video_12: (63, 64, 1000) -> Feature: (63, 64, 5)
#   [info] Video video_13: (111, 64, 1000) -> Feature: (111, 64, 5)
#   [info] Video video_14: (103, 64, 1000) -> Feature: (103, 64, 5)
#   [info] Video video_15: (170, 64, 1000) -> Feature: (170, 64, 5)
# [info] Save feature to: ./REFED-dataset/features\32\EEG_videos_feature.mat
# Processing EEG data of subject ID.[4]...
#   [info] Video video_1: (134, 64, 1000) -> Feature: (134, 64, 5)
#   [info] Video video_2: (137, 64, 1000) -> Feature: (137, 64, 5)
#   [info] Video video_3: (90, 64, 1000) -> Feature: (90, 64, 5)
#   [info] Video video_4: (79, 64, 1000) -> Feature: (79, 64, 5)
#   [info] Video video_5: (135, 64, 1000) -> Feature: (135, 64, 5)
#   [info] Video video_6: (93, 64, 1000) -> Feature: (93, 64, 5)
#   [info] Video video_7: (122, 64, 1000) -> Feature: (122, 64, 5)
#   [info] Video video_8: (107, 64, 1000) -> Feature: (107, 64, 5)
#   [info] Video video_9: (70, 64, 1000) -> Feature: (70, 64, 5)
#   [info] Video video_10: (60, 64, 1000) -> Feature: (60, 64, 5)
#   [info] Video video_11: (61, 64, 1000) -> Feature: (61, 64, 5)
#   [info] Video video_12: (63, 64, 1000) -> Feature: (63, 64, 5)
#   [info] Video video_13: (111, 64, 1000) -> Feature: (111, 64, 5)
#   [info] Video video_14: (103, 64, 1000) -> Feature: (103, 64, 5)
#   [info] Video video_15: (170, 64, 1000) -> Feature: (170, 64, 5)
# [info] Save feature to: ./REFED-dataset/features\4\EEG_videos_feature.mat
# Processing EEG data of subject ID.[5]...
#   [info] Video video_1: (134, 64, 1000) -> Feature: (134, 64, 5)
#   [info] Video video_2: (137, 64, 1000) -> Feature: (137, 64, 5)
#   [info] Video video_3: (90, 64, 1000) -> Feature: (90, 64, 5)
#   [info] Video video_4: (79, 64, 1000) -> Feature: (79, 64, 5)
#   [info] Video video_5: (135, 64, 1000) -> Feature: (135, 64, 5)
#   [info] Video video_6: (93, 64, 1000) -> Feature: (93, 64, 5)
#   [info] Video video_7: (122, 64, 1000) -> Feature: (122, 64, 5)
#   [info] Video video_8: (107, 64, 1000) -> Feature: (107, 64, 5)
#   [info] Video video_9: (70, 64, 1000) -> Feature: (70, 64, 5)
#   [info] Video video_10: (60, 64, 1000) -> Feature: (60, 64, 5)
#   [info] Video video_11: (61, 64, 1000) -> Feature: (61, 64, 5)
#   [info] Video video_12: (63, 64, 1000) -> Feature: (63, 64, 5)
#   [info] Video video_13: (111, 64, 1000) -> Feature: (111, 64, 5)
#   [info] Video video_14: (103, 64, 1000) -> Feature: (103, 64, 5)
#   [info] Video video_15: (170, 64, 1000) -> Feature: (170, 64, 5)
# [info] Save feature to: ./REFED-dataset/features\5\EEG_videos_feature.mat
# Processing EEG data of subject ID.[6]...
#   [info] Video video_1: (134, 64, 1000) -> Feature: (134, 64, 5)
#   [info] Video video_2: (137, 64, 1000) -> Feature: (137, 64, 5)
#   [info] Video video_3: (90, 64, 1000) -> Feature: (90, 64, 5)
#   [info] Video video_4: (79, 64, 1000) -> Feature: (79, 64, 5)
#   [info] Video video_5: (135, 64, 1000) -> Feature: (135, 64, 5)
#   [info] Video video_6: (93, 64, 1000) -> Feature: (93, 64, 5)
#   [info] Video video_7: (122, 64, 1000) -> Feature: (122, 64, 5)
#   [info] Video video_8: (107, 64, 1000) -> Feature: (107, 64, 5)
#   [info] Video video_9: (70, 64, 1000) -> Feature: (70, 64, 5)
#   [info] Video video_10: (60, 64, 1000) -> Feature: (60, 64, 5)
#   [info] Video video_11: (61, 64, 1000) -> Feature: (61, 64, 5)
#   [info] Video video_12: (63, 64, 1000) -> Feature: (63, 64, 5)
#   [info] Video video_13: (111, 64, 1000) -> Feature: (111, 64, 5)
#   [info] Video video_14: (103, 64, 1000) -> Feature: (103, 64, 5)
#   [info] Video video_15: (170, 64, 1000) -> Feature: (170, 64, 5)
# [info] Save feature to: ./REFED-dataset/features\6\EEG_videos_feature.mat
# Processing EEG data of subject ID.[7]...
#   [info] Video video_1: (134, 64, 1000) -> Feature: (134, 64, 5)
#   [info] Video video_2: (137, 64, 1000) -> Feature: (137, 64, 5)
#   [info] Video video_3: (90, 64, 1000) -> Feature: (90, 64, 5)
#   [info] Video video_4: (79, 64, 1000) -> Feature: (79, 64, 5)
#   [info] Video video_5: (135, 64, 1000) -> Feature: (135, 64, 5)
#   [info] Video video_6: (93, 64, 1000) -> Feature: (93, 64, 5)
#   [info] Video video_7: (122, 64, 1000) -> Feature: (122, 64, 5)
#   [info] Video video_8: (107, 64, 1000) -> Feature: (107, 64, 5)
#   [info] Video video_9: (70, 64, 1000) -> Feature: (70, 64, 5)
#   [info] Video video_10: (60, 64, 1000) -> Feature: (60, 64, 5)
#   [info] Video video_11: (61, 64, 1000) -> Feature: (61, 64, 5)
#   [info] Video video_12: (63, 64, 1000) -> Feature: (63, 64, 5)
#   [info] Video video_13: (111, 64, 1000) -> Feature: (111, 64, 5)
#   [info] Video video_14: (103, 64, 1000) -> Feature: (103, 64, 5)
#   [info] Video video_15: (170, 64, 1000) -> Feature: (170, 64, 5)
# [info] Save feature to: ./REFED-dataset/features\7\EEG_videos_feature.mat
# Processing EEG data of subject ID.[8]...
#   [info] Video video_1: (134, 64, 1000) -> Feature: (134, 64, 5)
#   [info] Video video_2: (137, 64, 1000) -> Feature: (137, 64, 5)
#   [info] Video video_3: (90, 64, 1000) -> Feature: (90, 64, 5)
#   [info] Video video_4: (79, 64, 1000) -> Feature: (79, 64, 5)
#   [info] Video video_5: (135, 64, 1000) -> Feature: (135, 64, 5)
#   [info] Video video_6: (93, 64, 1000) -> Feature: (93, 64, 5)
#   [info] Video video_7: (122, 64, 1000) -> Feature: (122, 64, 5)
#   [info] Video video_8: (107, 64, 1000) -> Feature: (107, 64, 5)
#   [info] Video video_9: (70, 64, 1000) -> Feature: (70, 64, 5)
#   [info] Video video_10: (60, 64, 1000) -> Feature: (60, 64, 5)
#   [info] Video video_11: (61, 64, 1000) -> Feature: (61, 64, 5)
#   [info] Video video_12: (63, 64, 1000) -> Feature: (63, 64, 5)
#   [info] Video video_13: (111, 64, 1000) -> Feature: (111, 64, 5)
#   [info] Video video_14: (103, 64, 1000) -> Feature: (103, 64, 5)
#   [info] Video video_15: (170, 64, 1000) -> Feature: (170, 64, 5)
# [info] Save feature to: ./REFED-dataset/features\8\EEG_videos_feature.mat
# Processing EEG data of subject ID.[9]...
#   [info] Video video_1: (134, 64, 1000) -> Feature: (134, 64, 5)
#   [info] Video video_2: (137, 64, 1000) -> Feature: (137, 64, 5)
#   [info] Video video_3: (90, 64, 1000) -> Feature: (90, 64, 5)
#   [info] Video video_4: (79, 64, 1000) -> Feature: (79, 64, 5)
#   [info] Video video_5: (135, 64, 1000) -> Feature: (135, 64, 5)
#   [info] Video video_6: (93, 64, 1000) -> Feature: (93, 64, 5)
#   [info] Video video_7: (122, 64, 1000) -> Feature: (122, 64, 5)
#   [info] Video video_8: (107, 64, 1000) -> Feature: (107, 64, 5)
#   [info] Video video_9: (70, 64, 1000) -> Feature: (70, 64, 5)
#   [info] Video video_10: (60, 64, 1000) -> Feature: (60, 64, 5)
#   [info] Video video_11: (61, 64, 1000) -> Feature: (61, 64, 5)
#   [info] Video video_12: (63, 64, 1000) -> Feature: (63, 64, 5)
#   [info] Video video_13: (111, 64, 1000) -> Feature: (111, 64, 5)
#   [info] Video video_14: (103, 64, 1000) -> Feature: (103, 64, 5)
#   [info] Video video_15: (170, 64, 1000) -> Feature: (170, 64, 5)
# [info] Save feature to: ./REFED-dataset/features\9\EEG_videos_feature.mat
